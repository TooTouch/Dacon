# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#split_data" data-toc-modified-id="split_data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>split_data</a></span></li><li><span><a href="#train_val_test" data-toc-modified-id="train_val_test-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>train_val_test</a></span></li><li><span><a href="#정규시즌" data-toc-modified-id="정규시즌-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>정규시즌</a></span></li><li><span><a href="#정규시즌-+-친선경기" data-toc-modified-id="정규시즌-+-친선경기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>정규시즌 + 친선경기</a></span></li></ul></div>

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')

import xgboost as xgb

# %%
def dummy_feature(df, variables):
    dummies = pd.DataFrame()
    for var in variables:
        dummy = pd.get_dummies(df[var], prefix=var, drop_first=True)
        dummies = pd.concat([dummies, dummy], axis=1)
        df = df.drop(var, axis=1)
    df = pd.concat([df, dummies], axis=1)
    return df

def preprocessing_data(data):
    data['height'] = data['height/weight'].apply(lambda x: np.nan if str(x) == 'nan' else x.split('/')[0][:3]).astype(float)
    data['weight'] = data['height/weight'].apply(lambda x: np.nan if str(x) == 'nan' else x.split('/')[1][:-2]).astype(float)
    data['age'] = data.year - data.year_born.apply(lambda x: int(x[:4]))
    data.starting_salary = data.starting_salary.apply(lambda x: x[:-2] if str(x)!='nan' else np.nan).astype(float) 
    
    data = dummy_feature(data, ['team','position'])
    data = data.drop('year_born', axis=1)
    data = data.drop('height/weight', axis=1)
    
    data.starting_salary = data.starting_salary.fillna(np.median(data.starting_salary.dropna()))
    data.height = data.height.fillna(np.median(data.height.dropna()))
    data.weight = data.weight.fillna(np.median(data.weight.dropna()))
    data = data.fillna(0)
    
    return data

# %%
data_regular = pd.read_csv('../dataset/Regular_Season_Batter.csv', index_col=0)
data_pre = pd.read_csv('../dataset/Pre_Season_Batter.csv', index_col=0)
data = pd.concat([data_regular, data_pre], axis=0)

# %%
data_regular.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2454 entries, 0 to 344
# Data columns (total 28 columns):
# batter_name        2454 non-null object
# year               2454 non-null int64
# team               2454 non-null object
# avg                2428 non-null float64
# G                  2454 non-null int64
# AB                 2454 non-null int64
# R                  2454 non-null int64
# H                  2454 non-null int64
# 2B                 2454 non-null int64
# 3B                 2454 non-null int64
# HR                 2454 non-null int64
# TB                 2454 non-null int64
# RBI                2454 non-null int64
# SB                 2454 non-null int64
# CS                 2454 non-null int64
# BB                 2454 non-null int64
# HBP                2454 non-null int64
# SO                 2454 non-null int64
# GDP                2454 non-null int64
# SLG                2428 non-null float64
# OBP                2430 non-null float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3847 entries, 0 to 344
# Data columns (total 28 columns):
# batter_name        3847 non-null object
# year               3847 non-null int64
# team               3847 non-null object
# avg                3821 non-null object
# G                  3847 non-null int64
# AB                 3847 non-null int64
# R                  3847 non-null int64
# H                  3847 non-null int64
# 2B                 3847 non-null int64
# 3B                 3847 non-null int64
# HR                 3847 non-null int64
# TB                 3847 non-null int64
# RBI                3847 non-null int64
# SB                 3847 non-null int64
# CS                 3847 non-null int64
# BB                 3847 non-null int64
# HBP                3847 non-null int64
# SO                 3847 non-null int64
# GDP                3847 non-null int64
# SLG                3792 non-null float64
# OBP                3798 non-null float64
# ...

# %%
features = ['year','team','height/weight','year_born','position','starting_salary','OPS']
data_regular = data_regular[features]
data = data[features]

# %%
data_regular.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2454 entries, 0 to 344
# Data columns (total 7 columns):
# year               2454 non-null int64
# team               2454 non-null object
# height/weight      1652 non-null object
# year_born          2454 non-null object
# position           1652 non-null object
# starting_salary    1387 non-null object
# OPS                2428 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 153.4+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3847 entries, 0 to 344
# Data columns (total 7 columns):
# year               3847 non-null int64
# team               3847 non-null object
# height/weight      3045 non-null object
# year_born          3847 non-null object
# position           3045 non-null object
# starting_salary    2566 non-null object
# OPS                3792 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 240.4+ KB

# %%
data_regular = preprocessing_data(data_regular)
data_regular.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2454 entries, 0 to 344
# Data columns (total 30 columns):
# year                  2454 non-null int64
# starting_salary       2454 non-null float64
# OPS                   2454 non-null float64
# height                2454 non-null float64
# weight                2454 non-null float64
# age                   2454 non-null int64
# team_KT               2454 non-null uint8
# team_LG               2454 non-null uint8
# team_NC               2454 non-null uint8
# team_OB               2454 non-null uint8
# team_SK               2454 non-null uint8
# team_넥센               2454 non-null uint8
# team_두산               2454 non-null uint8
# team_롯데               2454 non-null uint8
# team_삼성               2454 non-null uint8
# team_쌍방울              2454 non-null uint8
# team_우리               2454 non-null uint8
# team_한화               2454 non-null uint8
# team_해태               2454 non-null uint8
# team_현대               2454 non-null uint8
# ...

# %%
data = preprocessing_data(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3847 entries, 0 to 344
# Data columns (total 30 columns):
# year                  3847 non-null int64
# starting_salary       3847 non-null float64
# OPS                   3847 non-null float64
# height                3847 non-null float64
# weight                3847 non-null float64
# age                   3847 non-null int64
# team_KT               3847 non-null uint8
# team_LG               3847 non-null uint8
# team_NC               3847 non-null uint8
# team_OB               3847 non-null uint8
# team_SK               3847 non-null uint8
# team_넥센               3847 non-null uint8
# team_두산               3847 non-null uint8
# team_롯데               3847 non-null uint8
# team_삼성               3847 non-null uint8
# team_쌍방울              3847 non-null uint8
# team_우리               3847 non-null uint8
# team_한화               3847 non-null uint8
# team_해태               3847 non-null uint8
# team_현대               3847 non-null uint8
# ...

# %% [markdown]
# # split_data

# %%
x_data_regular = data_regular.drop('OPS',axis=1)
y_data_regular = data_regular.OPS

# %%
x_data = data.drop('OPS',axis=1)
y_data = data.OPS

# %%
f, ax = plt.subplots(1,1, figsize=(20,10))
sns.heatmap(data_regular.corr(), annot=True, fmt=".2f", ax=ax)
plt.show()

# %%
f, ax = plt.subplots(1,1, figsize=(20,10))
sns.heatmap(data.corr(), annot=True, fmt=".2f", ax=ax)
plt.show()

# %% [markdown]
# # train_val_test

# %%
x_train_regular = x_data_regular[(x_data_regular.year != 2018) & (x_data_regular.year != 2017)]
x_valid_regular = x_data_regular[x_data_regular.year == 2017]
x_test = x_data_regular[x_data_regular.year == 2018]

y_train_regular = y_data_regular[(x_data_regular.year != 2018) & (x_data_regular.year != 2017)]
y_valid_regular = y_data_regular[x_data_regular.year == 2017]
y_test = y_data_regular[x_data_regular.year == 2018]

x_train_regular = x_train_regular.drop('year', axis=1)
x_valid_regular = x_valid_regular.drop('year', axis=1)
x_test = x_test.drop('year', axis=1)

# %%
x_train = x_data[(x_data.year != 2018) & (x_data.year != 2017)]
x_valid = x_data[x_data.year == 2017]

y_train = y_data[(x_data.year != 2018) & (x_data.year != 2017)]
y_valid = y_data[x_data.year == 2017]

x_train = x_train.drop('year', axis=1)
x_valid = x_valid.drop('year', axis=1)

# %%
params = {
    "learning_rate": 0.1,
    "n_estimators": 10000,
    "max_depth": 3,
    "min_child_weight": 5,
    "subsample": 1.0,
    "colsample_bytree": 1.0,
    "colsample_bylevel": 1.0,
    "alpha": 0,
    "lambda": 1,
    "objective": "gpu:reg:linear",
    "tree_method": "gpu_hist",
    "predictor": "gpu_predictor",
    "eval_metric":"rmse"
}
model_regular = xgb.XGBRegressor(**params)
model = xgb.XGBRegressor(**params)

# %% [markdown]
# # 정규시즌

# %%
model_regular.fit(x_train_regular, y_train_regular, eval_set=[(x_train_regular, y_train_regular), (x_valid_regular, y_valid_regular)], early_stopping_rounds=100, verbose=50)
# Out:
# [0]	validation_0-rmse:0.297099	validation_1-rmse:0.278181
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [50]	validation_0-rmse:0.237031	validation_1-rmse:0.213642
# [100]	validation_0-rmse:0.229576	validation_1-rmse:0.211908
# [150]	validation_0-rmse:0.225403	validation_1-rmse:0.211694
# [200]	validation_0-rmse:0.221774	validation_1-rmse:0.211671
# Stopping. Best iteration:
# [143]	validation_0-rmse:0.226071	validation_1-rmse:0.211363
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1.0,
#        colsample_bytree=1.0, eval_metric='rmse', gamma=0, lambda=1,
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=5, missing=None, n_estimators=10000, n_jobs=1,
#        nthread=None, objective='gpu:reg:linear', predictor='gpu_predictor',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
# ...

# %%
prob_regular = model_regular.predict(x_test, ntree_limit=model_regular.best_iteration)
rmse = np.sqrt(np.mean(np.power(y_test-prob_regular, 2)))
print('test RMSE: {0:.6f}'.format(rmse))
# Out:
# test RMSE: 0.230878

# %%
sns.distplot(y_test, label='true')
sns.distplot(prob_regular, label='pred')
plt.legend(loc='upper right')
# Out:
# C:\Users\wogur\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
weight_score_regular = model_regular.get_booster().get_score(importance_type='weight')
gain_score_regular = model_regular.get_booster().get_score(importance_type='gain')
cover_score_regular = model_regular.get_booster().get_score(importance_type='cover')

weight_score_regular_df = pd.DataFrame({'feature':list(weight_score_regular.keys()), 'score':list(weight_score_regular.values())})
gain_score_regular_df = pd.DataFrame({'feature':list(gain_score_regular.keys()), 'score':list(gain_score_regular.values())})
cover_score_regular_df = pd.DataFrame({'feature':list(cover_score_regular.keys()), 'score':list(cover_score_regular.values())})

f, ax = plt.subplots(1,3, figsize=(15,10))
sns.barplot(x='score', y='feature', data=weight_score_regular_df.sort_values(by='score', ascending=False), ax=ax[0])
sns.barplot(x='score', y='feature', data=gain_score_regular_df.sort_values(by='score', ascending=False), ax=ax[1])
sns.barplot(x='score', y='feature', data=cover_score_regular_df.sort_values(by='score', ascending=False), ax=ax[2])

# %% [markdown]
# # 정규시즌 + 친선경기

# %%
model.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_valid, y_valid)], early_stopping_rounds=100, verbose=50)
# Out:
# [0]	validation_0-rmse:0.332732	validation_1-rmse:0.330065
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [50]	validation_0-rmse:0.283041	validation_1-rmse:0.281622
# [100]	validation_0-rmse:0.276187	validation_1-rmse:0.282992
# Stopping. Best iteration:
# [26]	validation_0-rmse:0.288452	validation_1-rmse:0.279258
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1.0,
#        colsample_bytree=1.0, eval_metric='rmse', gamma=0, lambda=1,
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=5, missing=None, n_estimators=10000, n_jobs=1,
#        nthread=None, objective='gpu:reg:linear', predictor='gpu_predictor',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1.0, tree_method='gpu_hist')

# %%
prob = model.predict(x_test, ntree_limit=model.best_iteration)
rmse = np.sqrt(np.mean(np.power(y_test-prob, 2)))
print('test RMSE: {0:.6f}'.format(rmse))
# Out:
# test RMSE: 0.233662

# %%
sns.distplot(y_test, label='true')
sns.distplot(prob, label='pred')
plt.legend(loc='upper right')
# Out:
# C:\Users\wogur\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
weight_score_regular = model_regular.get_booster().get_score(importance_type='weight')
gain_score_regular = model_regular.get_booster().get_score(importance_type='gain')
cover_score_regular = model_regular.get_booster().get_score(importance_type='cover')

weight_score_regular_df = pd.DataFrame({'feature':list(weight_score_regular.keys()), 'score':list(weight_score_regular.values())})
gain_score_regular_df = pd.DataFrame({'feature':list(gain_score_regular.keys()), 'score':list(gain_score_regular.values())})
cover_score_regular_df = pd.DataFrame({'feature':list(cover_score_regular.keys()), 'score':list(cover_score_regular.values())})

f, ax = plt.subplots(1,3, figsize=(15,10))
sns.barplot(x='score', y='feature', data=weight_score_regular_df.sort_values(by='score', ascending=False), ax=ax[0])
sns.barplot(x='score', y='feature', data=gain_score_regular_df.sort_values(by='score', ascending=False), ax=ax[1])
sns.barplot(x='score', y='feature', data=cover_score_regular_df.sort_values(by='score', ascending=False), ax=ax[2])
